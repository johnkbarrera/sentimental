# %%
# pip install emoji
# pip install tweepy

# %%
import pymysql

# Clase User
class User(object):
    def __init__(self):
        self.id = ""
        self.created = ""
        self.name = ""
        self.tag = ""
        self.location = ""
        self.description = None
        self.followersCount = 0
        self.friendsCount= 0
        self.favouritesCount = 0
        
    def __init__(self,id,fechaCreacion,nombre,tag,ubicacion,descripcion,followersCount,friendsCount,favouritesCount):
        self.id = id
        self.fechaCreacion = fechaCreacion
        self.nombre = nombre
        self.tag = tag
        self.ubicacion = ubicacion
        self.descripcion = descripcion
        self.followersCount = followersCount
        self.friendsCount = friendsCount
        self.favouritesCount = favouritesCount

    def getId(self):
        return self.id

    
    def agregarUsuario(self):
        try:
            connection = pymysql.connect(host = 'localhost', user = 'root',password = 'root',
                                         db = 'dbtwitter')
            
            with connection.cursor() as cursor:
                sentenciaSQL = "INSERT INTO dbtwitter.usuario(id,fechaCreacion,nombre,tag,ubicacion,descripcion,followersCount,friendsCount,favouritesCount) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s)"
                
                cursor.execute(sentenciaSQL, (str(self.id), self.fechaCreacion, str(self.nombre), str(self.tag), str(self.ubicacion), 
                                              str(self.descripcion), self.followersCount, self.friendsCount, self.favouritesCount))
                connection.commit()
                
        except Exception as e:
            print("Error on_data: %s" % str(e))
        finally:
            connection.close()
                         
    def __str__(self):
        return "{0}|{1}|{2}|{3}|{4}|{5}|{6}|{7}".format(self.id, 
                                                        self.fechaCreacion, 
                                                        self.nombre,
                                                        self.tag,
                                                        self.ubicacion,
                                                        self.descripcion,
                                                        self.followersCount,
                                                        self.friendsCount,
                                                        self.favouritesCount)

# %%
class Tweet(object):
    
    #metodo para inicializar la clase
    def __init__(self):
        self.id = ""
        self.fechaCreacion = ""
        self.contenido = ""
        self.user = None
   
    def __init__(self,id,fechaCreacion,contenido,user):
        self.id = id
        self.fechaCreacion = fechaCreacion
        self.contenido = contenido
        self.user = user
    
    def agregarTweet(self):
        try:
            connection = pymysql.connect(host = 'localhost', user = 'root',password = 'root',
                                         db = 'dbtwitter')
            
            with connection.cursor() as cursor:             
                sentenciaSQL=("INSERT INTO dbtwitter.tweet(id,fechaCreacion,texto,idUsuario) VALUES (%s,%s,%s,%s)")
                
                cursor.execute(sentenciaSQL, (str(self.id), self.fechaCreacion, str(self.contenido), str(self.user)))
                
                connection.commit()
                
        except Exception as e:
            print("Error on_data: %s" % str(e))
        finally:
            connection.close()
    
    def __str__(self):
        return "{0}|{1}|{2}|{3}".format(self.id,self.fechaCreacion,self.contenido,self.user)

# %%
import re
import emoji
import time
from datetime import datetime

class UtilTwitter(object):
    
    emojin_pattern = re.compile("["
                                u"\U0001F600-\U0001F64F" # emoticons
                                u"\U0001F300-\U0001F5FF" # symbols & pictographs
                                u"\U0001F680-\U0001F6FF" # transport & map symbols
                                u"\U0001F1E0-\U0001F1FF" # flags (iOS)
                                u"\U00002702-\U000027B0"
                                u"\U00002600-\U000027BF"
                                u"\U0001f300-\U0001f64F"
                                u"\U000024C2-\U0001F251"
                                "]+", flags=re.UNICODE)
    
    @staticmethod
    def format_datetime(text):
        datetime_object = datetime.strptime(text,'%a %b %d %H:%M:%S %z %Y')
        return datetime_object.strftime('%Y-%m-%d %H:%M:%S')
    
    @staticmethod
    def remove_emoticon(text):
        free_emoticon = ''.join(c for c in text if c not in emoji.UNICODE_EMOJI)
        return UtilTwitter.emojin_pattern.sub(r'', free_emoticon)
    
    @staticmethod
    def clear_text(text:str):
        if text is None:
            return "Indefinido"
        elif text.strip() == "":
            return "Indefinido"
        else:
            return " ".join(re.findall("[a-zA-Z]+", text))

# %%
import unittest

class UtilTwitterTest(unittest.TestCase):
    
    def test_format_datetime(self):
        self.assertEqual("2018-11-07 07:32:57",UtilTwitter.format_datetime('Wed Nov 07 07:32:57 +0000 2018'))
    
    def test_clear_text(self):
        self.assertEqual("nadya", UtilTwitter.clear_text("nadya🥀"))
                                                                           
    def test_clear_none(self):
        self.assertEqual("Indefinido", UtilTwitter.clear_text(None))
                                                                           
    def test_clear_vacio(self):
        self.assertEqual("Indefinido", UtilTwitter.clear_text("  "))
        ###Completar código###
                                                                           
if __name__ == "__main__":
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.008s
#
# OK

# %%
import tweepy

import time
import json

class TwitterListener(tweepy.StreamListener):
    """Custom StreamListener for streaming data."""
    def __init__(self, time_limit=60):
        self.start_time = time.time()
        self.limit = time_limit
        
    def on_data(self, tweet_json):
        if (time.time() - self.start_time) < self.limit:
            tweet_json = tweet_json.encode('utf-8')
            decoded = json.loads(tweet_json)
            print(decoded)
            try:
                #Obtener datos Usuario
                userjson = decoded.get('user')
                id_user = userjson.get('id')
                created_user = UtilTwitter.format_datetime(userjson.get('created_at'))
                name_user = UtilTwitter.clear_text(userjson.get('name'))
                tag_user = UtilTwitter.clear_text(userjson.get('screen_name'))
                location_user = UtilTwitter.clear_text(userjson.get('location'))
                description_user = UtilTwitter.clear_text(userjson.get('description'))
                followersCount_user = userjson.get('followers_count')
                friendsCount_user = userjson.get('friends_count')
                favouritesCount_user = userjson.get('favourites_count')

                #Obtener datos Tweet
                id_tweet = decoded.get('id_str')
                text_tweet = UtilTwitter.remove_emoticon(decoded.get('text'))
                created_tweet = UtilTwitter.format_datetime(decoded.get('created_at'))

                oUser = User(id_user,created_user,name_user,"@"+tag_user,location_user,description_user,followersCount_user,
                             friendsCount_user,favouritesCount_user)
                print(oUser)

                oTweet = Tweet(id_tweet, created_tweet, text_tweet, id_user)
                print(oTweet)

                oUser.agregarUsuario()
                oTweet.agregarTweet()

            except BaseException as e:
                print("Error on_data: %s" % str(e))
                time.sleep(5)
            return True
        else:
            return False #Kill current stream
        
    def on_error(self, status):
        print("Error status: " + str(status))
        return True
        
    def on_timeout(self):
        print ('Timeout...')
        return True # Don't kill the stream

# %%
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

class ExtraccionTwitterCtrl(object):
    
    #Credenciales de cuenta Twitter
    CONSUMER_KEY = '9mwmv7Yt5R783Jry1bYEiGe2n'
    CONSUMER_SECRET = 'NQazRU4BpfmfwKmWD2pxhebAjitfEFOPHErOKTrWjBrn4jpXSE'
    ACCESS_TOKEN = '442102127-wvZfxbOkw3V8eQfbJgI7iSkyokI96tw8U2u5ROj0'
    ACCESS_SECRET = 'L0PJfiYiT0cToCgZKDv6fMJD64iPbr0V9D6S0eHiVXRuW'

    def __init__(self):
        # Autenticación
        self.auth = OAuthHandler(self.CONSUMER_KEY, self.CONSUMER_SECRET)
        self.auth.set_access_token(self.ACCESS_TOKEN, self.ACCESS_SECRET)
    
    def filterByText(self, list_tag, time_limit):
        print("Inicio de filterByText\n")
        try:
            twitter_stream = tweepy.streaming.Stream(self.auth, TwitterListener(time_limit))
            twitter_stream.filter(track=list_tag)
        except (KeyboardInterrupt, SystemExit):
            print("Parar proceso de extracción\n")
        print("Fin de filterByText\n")
     
    def filterByLocations(self, loc, time_limit):
        print("Inicio de filterByLocations\n")
        try:
            twitter_stream = tweepy.streaming.Stream(self.auth, TwitterListener(time_limit))
            twitter_stream.filter(locations = loc)
        except (KeyboardInterrupt, SystemExit):
            print("Parar proceso de extracción\n")
        print("Fin de filterByLocations\n")

    def filterByUsers(self, users, time_limit):
        print("Inicio de filterByUsers\n")
        try:
            twitter_stream = tweepy.streaming.Stream(self.auth, TwitterListener(time_limit))            
            twitter_stream = tweepy.streaming.Stream(self.auth, TwitterListener())
            twitter_stream.filter(follow = users)
        except (KeyboardInterrupt, SystemExit):
            print("Parar proceso de extracción\n")
        print("Fin de filterByLocations\n")
    
    def filterByMe(self, list_tag, loc, time_limit):
        print("Inicio de filterByText\n")
        try:
            twitter_stream = tweepy.streaming.Stream(self.auth, TwitterListener(time_limit))
            twitter_stream.filter(track = list_tag, locations = loc, languages=['es'])
        except (KeyboardInterrupt, SystemExit):
            print("Parar proceso de extracción\n")
        print("Fin de filterByText\n")

# %%
hash_tag=['KeikoFujimori']

users_tag = ['385059774']  # 385059774

france=[-5.1406, 41.333740, 9.559320, 51.089062]
spain =[-4.042280, 40.611900, -4.023130,40.630329]
italy=[-96.901863,32.171291, -96.866524, 32.204861]
germany = [5.866240,47.270210, 15.042050,55.058140]
peru = [ -81.326736,-18.34972, -68.677979, -0.01297]
senegal =[ -17.535231,12.30727, -11.35588,16.691629]
costaMarfil =[-8.5993,4.35706, -2.49489,10.73664]

# %%
oExtraccion = ExtraccionTwitterCtrl()

# %%
# oExtraccion.filterByText(hash_tag, 100)

# %%
 oExtraccion.filterByLocations(peru, 10)
# Out:
# Inicio de filterByLocations
#
# {'created_at': 'Sat Nov 17 19:35:05 +0000 2018', 'id': 1063878210075672576, 'id_str': '1063878210075672576', 'text': '#Machala #eloro #empleo  https://t.co/McelTDSbWc', 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'truncated': False, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1006010751218274305, 'id_str': '1006010751218274305', 'name': 'Grasshopper Tienda Garage', 'screen_name': 'EcuGrasshopper', 'location': 'Guayaquil, Ecuador', 'url': 'http://www.grasshopper.store', 'description': 'Somos una #tiendaonline creada por #emprendedores #ecuatorianos en la ciudad de #guayaquil, encuentra de todo al menor precio en http://www.grasshopper.store', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 74, 'friends_count': 607, 'listed_count': 0, 'favourites_count': 711, 'statuses_count': 902, 'created_at': 'Mon Jun 11 03:10:28 +0000 2018', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': '', 'profile_background_image_url_https': '', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1006011957860806656/5FPE6Ep1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1006011957860806656/5FPE6Ep1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1006010751218274305/1536059592', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': {'id': '01055c04268d0326', 'url': 'https://api.twitter.com/1.1/geo/id/01055c04268d0326.json', 'place_type': 'city', 'name': 'Machala', 'full_name': 'Machala, Ecuador', 'country_code': 'EC', 'country': 'Ecuador', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-80.034352, -3.435801], [-80.034352, -3.192298], [-79.842269, -3.192298], [-79.842269, -3.435801]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [{'text': 'Machala', 'indices': [0, 8]}, {'text': 'eloro', 'indices': [9, 15]}, {'text': 'empleo', 'indices': [16, 23]}], 'urls': [{'url': 'https://t.co/McelTDSbWc', 'expanded_url': 'https://www.eventbrite.es/e/expo-empleo-machala-2019-tickets-52756829096?ref=eios&aff=eios', 'display_url': 'eventbrite.es/e/expo-empleo-…', 'indices': [25, 48]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'filter_level': 'low', 'lang': 'und', 'timestamp_ms': '1542483305840'}
# 1006010751218274305|2018-06-11 03:10:28|Grasshopper Tienda Garage|@EcuGrasshopper|Guayaquil Ecuador|Somos una tiendaonline creada por emprendedores ecuatorianos en la ciudad de guayaquil encuentra de todo al menor precio en http www grasshopper store|74|607
# 1063878210075672576|2018-11-17 19:35:05|#Machala #eloro #empleo  https://t.co/McelTDSbWc|1006010751218274305
# {'created_at': 'Sat Nov 17 19:35:06 +0000 2018', 'id': 1063878214249005062, 'id_str': '1063878214249005062', 'text': 'Estoy esperando que el señor Valencia diga que Melgar va a ganar la semifinal, para que lo terminé de salar y Alian… https://t.co/6uPSVEf1e8', 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1267862582, 'id_str': '1267862582', 'name': 'jesus ALberto', 'screen_name': 'jachq', 'location': None, 'url': None, 'description': 'Hincha del club mas popular del Perú Alianza Lima y del teatro en general, no uso billetera, ni reloj, ni cadenas, me gustan los tatuajes y nada más por ahora.', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 412, 'friends_count': 615, 'listed_count': 4, 'favourites_count': 56956, 'statuses_count': 19387, 'created_at': 'Thu Mar 14 19:56:05 +0000 2013', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/619383674992230400/j6-Jrngk_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/619383674992230400/j6-Jrngk_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1267862582/1534644173', 'default_profile': True, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': {'id': '006099b7317c8404', 'url': 'https://api.twitter.com/1.1/geo/id/006099b7317c8404.json', 'place_type': 'city', 'name': 'Lima', 'full_name': 'Lima, Peru', 'country_code': 'PE', 'country': 'Peru', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-77.088074, -12.080577], [-77.088074, -12.030359], [-76.999859, -12.030359], [-76.999859, -12.080577]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Estoy esperando que el señor Valencia diga que Melgar va a ganar la semifinal, para que lo terminé de salar y Alianza pase automáticamente a la final, y espero que diga después que sc a a ser campeón para así ir celebrando el bicampeonato de Alianza @oscarpaz20 @JeanRod28', 'display_text_range': [0, 272], 'entities': {'hashtags': [], 'urls': [], 'user_mentions': [{'screen_name': 'oscarpaz20', 'name': 'Oscar Paz', 'id': 60512355, 'id_str': '60512355', 'indices': [250, 261]}, {'screen_name': 'JeanRod28', 'name': 'Jean Rodriguez', 'id': 550677433, 'id_str': '550677433', 'indices': [262, 272]}], 'symbols': []}}, 'quote_count': 0, 'reply_count': 0, 'retweet_count': 0, 'favorite_count': 0, 'entities': {'hashtags': [], 'urls': [{'url': 'https://t.co/6uPSVEf1e8', 'expanded_url': 'https://twitter.com/i/web/status/1063878214249005062', 'display_url': 'twitter.com/i/web/status/1…', 'indices': [117, 140]}], 'user_mentions': [], 'symbols': []}, 'favorited': False, 'retweeted': False, 'filter_level': 'low', 'lang': 'es', 'timestamp_ms': '1542483306835'}
# 1267862582|2013-03-14 19:56:05|jesus ALberto|@jachq|Indefinido|Hincha del club mas popular del Per Alianza Lima y del teatro en general no uso billetera ni reloj ni cadenas me gustan los tatuajes y nada m s por ahora|412|615
# 1063878214249005062|2018-11-17 19:35:06|Estoy esperando que el señor Valencia diga que Melgar va a ganar la semifinal, para que lo terminé de salar y Alian… https://t.co/6uPSVEf1e8|1267862582
# {'created_at': 'Sat Nov 17 19:35:11 +0000 2018', 'id': 1063878233396051968, 'id_str': '1063878233396051968', 'text': 'Puntos claves de una Promoción…\n1-Hit\n2-Financiamiento\n3-Equipo de Trabajo\n4- Paciencia\n#sinosabepregunte   no coma… https://t.co/6vMJIlVcmy', 'display_text_range': [0, 140], 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'truncated': True, 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 447547760, 'id_str': '447547760', 'name': 'Wacho Fernandez', 'screen_name': 'Promo_Fernandez', 'location': 'GUAYAQUIL - ECUADOR', 'url': None, 'description': 'REPRESENTANTE ARTISTICO / DIRECTOR DE RADIOS / PRODUCTOR DE EVENTOS/ PROMOTOR MUSICAL HOMBRE DE RESULTADOS TRABAJADOR , HONESTO LEAL  HUMANO .', 'translator_type': 'none', 'protected': False, 'verified': False, 'followers_count': 2842, 'friends_count': 4341, 'listed_count': 47, 'favourites_count': 6284, 'statuses_count': 31984, 'created_at': 'Tue Dec 27 01:12:55 +0000 2011', 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'lang': 'es', 'contributors_enabled': False, 'is_translator': False, 'profile_background_color': '1A1B1F', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif', 'profile_background_tile': False, 'profile_link_color': 'FA743E', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '252429', 'profile_text_color': '666666', 'profile_use_background_image': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1021435114897715200/09TemdM3_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1021435114897715200/09TemdM3_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/447547760/1532364164', 'default_profile': False, 'default_profile_image': False, 'following': None, 'follow_request_sent': None, 'notifications': None}, 'geo': None, 'coordinates': None, 'place': {'id': '0177bc687a9ac697', 'url': 'https://api.twitter.com/1.1/geo/id/0177bc687a9ac697.json', 'place_type': 'city', 'name': 'Quito', 'full_name': 'Quito, Ecuador', 'country_code': 'EC', 'country': 'Ecuador', 'bounding_box': {'type': 'Polygon', 'coordinates': [[[-78.948466, -0.588618], [-78.948466, 0.255477], [-78.164897, 0.255477], [-78.164897, -0.588618]]]}, 'attributes': {}}, 'contributors': None, 'is_quote_status': False, 'extended_tweet': {'full_text': 'Puntos claves de una Promoción…\n1-Hit\n2-Financiamiento\n3-Equipo de Trabajo\n4- Paciencia\n#sinosabepregunte   no coman cuento !#artistas #talento #latino #cantantes #gye Contacto 0987649031 Promoción con Resultados https://t.co/9AOTzK6Kq6', 'display_text_range': [0, 212], 'entities': {'hashtags': [{'text': 'sinosabepregunte', 'indices': [88, 105]}, {'text': 'artistas', 'indices': [125, 134]}, {'text': 'talento', 'indices': [135, 143]}, {'text': 'latino', 'indices': [144, 151]}, {'text': 'cantantes', 'indices': [152, 162]}, {'text': 'gye', 'indices': [163, 167]}], 'urls': [], 'user_mentions': [], 'symbols': [], 'media': [{'id': 1063878225036742663, 'id_str': '1063878225036742663', 'indices': [213, 236], 'media_url': 'http://pbs.twimg.com/media/DsOnm-eWkAcF5A7.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DsOnm-eWkAcF5A7.jpg', 'url': 'https://t.co/9AOTzK6Kq6', 'display_url': 'pic.twitter.com/9AOTzK6Kq6', 'expanded_url': 'https://twitter.com/Promo_Fernandez/status/1063878233396051968/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 480, 'h': 480, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 480, 'h': 480, 'resize': 'fit'}, 'large': {'w': 480, 'h': 480, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1063878225036742663, 'id_str': '1063878225036742663', 'indices': [213, 236], 'media_url': 'http://pbs.twi ...
# 447547760|2011-12-27 01:12:55|Wacho Fernandez|@Promo Fernandez|GUAYAQUIL ECUADOR|REPRESENTANTE ARTISTICO DIRECTOR DE RADIOS PRODUCTOR DE EVENTOS PROMOTOR MUSICAL HOMBRE DE RESULTADOS TRABAJADOR HONESTO LEAL HUMANO|2842|4341
# 1063878233396051968|2018-11-17 19:35:11|Puntos claves de una Promoción…
# 1-Hit
# 2-Financiamiento
# 3-Equipo de Trabajo
# 4- Paciencia
# #sinosabepregunte   no coma… https://t.co/6vMJIlVcmy|447547760
# Fin de filterByLocations

# %%
# oExtraccion.filterByMe(hash_tag, peru, 100)

# %%
#oExtraccion.filterByUsers(users_tag, 1000)
